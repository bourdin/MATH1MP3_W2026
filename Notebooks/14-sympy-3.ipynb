# %% [markdown]
# # 18-4 Plotting with sympy
#
# We saw that matplotlib provides tools for graphics which can be used for scientific plotting. Sympy provide "higher-level" function, geared towards mathematical plotting.
#
# ## "basic" usage

# %%
import sympy as sp
import numpy as np
# %matplotlib widget

# %%
# A general Gaussian function:
(sigma, mu, x) = sp.symbols( ('sigma', 'mu', 'x') )
gaussian = sp.exp(-(x-mu)**2/sigma**2/2)/sigma/sp.sqrt(2*sp.pi)
gaussian
# Out:
# sqrt(2)*exp(-(-mu + x)**2/(2*sigma**2))/(2*sqrt(pi)*sigma)

# %%
p = sp.plot(gaussian.subs( {sigma:1, mu:0}))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Here, matplotlib did the low-level plotting (we'll see that we can change this), driven by sympy.
# Note how sympy knows how to setup axes etc.
#
# See the help page for plot for more options

# %%
help(sp.plot)
# Out:
# Help on function plot in module sympy.plotting.plot:
#
# plot(*args, show=True, **kwargs)
#     Plots a function of a single variable as a curve.
#
#     Parameters
#     ==========
#
#     args :
#         The first argument is the expression representing the function
#         of single variable to be plotted.
#
#         The last argument is a 3-tuple denoting the range of the free
#         variable. e.g. ``(x, 0, 5)``
#
#         Typical usage examples are in the following:
#
#         - Plotting a single expression with a single range.
#             ``plot(expr, range, **kwargs)``
#         - Plotting a single expression with the default range (-10, 10).
#             ``plot(expr, **kwargs)``
#         - Plotting multiple expressions with a single range.
#             ``plot(expr1, expr2, ..., range, **kwargs)``
#         - Plotting multiple expressions with multiple ranges.
#             ``plot((expr1, range1), (expr2, range2), ..., **kwargs)``
#
#         It is best practice to specify range explicitly because default
#         range may change in the future if a more advanced default range
#         detection algorithm is implemented.
#
#     show : bool, optional
#         The default value is set to ``True``. Set show to ``False`` and
#         the function will not display the plot. The returned instance of
#         the ``Plot`` class can then be used to save or display the plot
#         by calling the ``save()`` and ``show()`` methods respectively.
#
#     line_color : string, or float, or function, optional
#         Specifies the color for the plot.
#         See ``Plot`` to see how to set color for the plots.
#         Note that by setting ``line_color``, it would be applied simultaneously
#         to all the series.
#
#     title : str, optional
#         Title of the plot. It is set to the latex representation of
#         the expression, if the plot has only one expression.
#
#     label : str, optional
#         The label of the expression in the plot. It will be used when
#         called with ``legend``. Default is the name of the expression.
#         e.g. ``sin(x)``
#
#     xlabel : str or expression, optional
#         Label for the x-axis.
#
#     ylabel : str or expression, optional
#         Label for the y-axis.
#
#     xscale : 'linear' or 'log', optional
#         Sets the scaling of the x-axis.
#
#     yscale : 'linear' or 'log', optional
#         Sets the scaling of the y-axis.
#
#     axis_center : (float, float), optional
#         Tuple of two floats denoting the coordinates of the center or
#         {'center', 'auto'}
#
#     xlim : (float, float), optional
#         Denotes the x-axis limits, ``(min, max)```.
#
#     ylim : (float, float), optional
#         Denotes the y-axis limits, ``(min, max)```.
#
#     annotations : list, optional
#         A list of dictionaries specifying the type of annotation
#         required. The keys in the dictionary should be equivalent
#         to the arguments of the :external:mod:`matplotlib`'s
#         :external:meth:`~matplotlib.axes.Axes.annotate` method.
#
#     markers : list, optional
#         A list of dictionaries specifying the type the markers required.
#         The keys in the dictionary should be equivalent to the arguments
#         of the :external:mod:`matplotlib`'s :external:func:`~matplotlib.pyplot.plot()` function
#         along with the marker related keyworded arguments.
#
#     rectangles : list, optional
#         A list of dictionaries specifying the dimensions of the
#         rectangles to be plotted. The keys in the dictionary should be
#         equivalent to the arguments of the :external:mod:`matplotlib`'s
#         :external:class:`~matplotlib.patches.Rectangle` class.
#
#     fill : dict, optional
#         A dictionary specifying the type of color filling required in
#         the plot. The keys in the dictionary should be equivalent to the
#         arguments of the :external:mod:`matplotlib`'s
#         :external:meth:`~matplotlib.axes.Axes.fill_between` method.
#
#     adaptive : bool, optional
#         The default value for the ``adaptive`` parameter is now ``False``.
#         To enable adaptive sampling, set ``adaptive=True`` and specify ``n`` if uniform sampling is required.
#
#         The plotting uses an adaptive algorithm which samples
#         recursively to accurately plot. The adaptive algorithm uses a
#         random point near the midpoint of two points that has to be
#         further sampled. Hence the same plots can appear slightly
#         different.
#
#     depth : int, optional
#         Recursion depth of the adaptive algorithm. A depth of value
#         `n` samples a maximum of `2^{n}` points.
#
#         If the ``adaptive`` flag is set to ``False``, this will be
#         ignored.
#
#     n : int, optional
#         Used when the ``adaptive`` is set to ``False``. The function
#         is uniformly sampled at ``n`` number of points. If the ``adaptive``
#         flag is set to ``True``, this will be ignored.
#         This keyword argument replaces ``nb_of_points``, which should be
#         considered deprecated.
#
#     size : (float, float), optional
#         A tuple in the form (width, height) in inches to specify the size of
#         the overall figure. The default value is set to ``None``, meaning
#         the size will be set by the default backend.
#
#     Examples
#     ========
#
#     .. plot::
#        :context: close-figs
#        :format: doctest
#        :include-source: True
#
#        >>> from sympy import symbols
#        >>> from sympy.plotting import plot
#        >>> x = symbols('x')
#
#     Single Plot
#
#     .. plot::
#        :context: close-figs
#        :format: doctest
#        :include-source: True
#
#        >>> plot(x**2, (x, -5, 5))
#        Plot object containing:
#        [0]: cartesian line: x**2 for x over (-5.0, 5.0)
#
#     Multiple plots with single range.
#
#     .. plot::
#        :context: close-figs
#        :format: doctest
#        :include-source: True
#
#        >>> plot(x, x**2, x**3, (x, -5, 5))
#        Plot object containing:
#        [0]: cartesian line: x for x over (-5.0, 5.0)
#        [1]: cartesian line: x**2 for x over (-5.0, 5.0)
#        [2]: cartesian line: x**3 for x over (-5.0, 5.0)
#
#     Multiple plots with different ranges.
#
#     .. plot::
#        :context: close-figs
#        :format: doctest
#        :include-source: True
#
#        >>> plot((x**2, (x, -6, 6)), (x, (x, -5, 5)))
#        Plot object containing:
#        [0]: cartesian line: x**2 for x over (-6.0, 6.0)
#        [1]: cartesian line: x for x over (-5.0, 5.0)
#
#     No adaptive sampling by default. If adaptive sampling is required, set ``adaptive=True``.
#
#     .. plot::
#        :context: close-figs
#        :format: doctest
#        :include-source: True
#
#        >>> plot(x**2, adaptive=True, n=400)
#        Plot object containing:
#        [0]: cartesian line: x**2 for x over (-10.0, 10.0)
#
#     See Also
#     ========
#
#     Plot, LineOver1DRangeSeries

# %%
p = sp.plot( (gaussian.subs( {'mu':0, 'sigma':1}), (x, -5,5), r'$\sigma = 1$'),
          (gaussian.subs( {'mu':0, 'sigma':2}), (x, -5,5), r'$\sigma = 2$'),
          title = "Gaussians",
          xlim = (-6,6),
          legend = True,
        )
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# We can make changes to the figure, but we will have to replot it for the changes to show:

# %%
p.title = "Two Gaussian functions"
p.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# `p` is a complex object, essentially equivalent to a collection of plots so that `p[0]` and `p[1]` are respectively the first and second plot and can be modified separately:

# %%
p[:]
# Out:
# [<sympy.plotting.series.LineOver1DRangeSeries at 0x128687750>,
#  <sympy.plotting.series.LineOver1DRangeSeries at 0x128704550>]

# %%
p[0].line_color = 'red'
p[1].label = r'Another gaussian'
p.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# We can also defer the actual plotting so that we can make all changes before rendering:

# %%
p2 = sp.plot( (gaussian.subs( {'mu':0, 'sigma':1})),
          (gaussian.subs( {'mu':0, 'sigma':2})), show = False)

# %%
p2.title = 'Another plot'
p2.legend = True
p2.xlim = (-5,5)
p2[0].label = 'Gaussian #1'
p2[1].label = 'Gaussian #2'
p2[1].line_color = 'red'

p2.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Note that since `p2` is a list of plots, we can easily add an extra curve to it:

# %%
p3 = sp.plot(sp.sinc(sp.pi*x)/2, (x, -10,10), label = r'$sinc(\pi x)$', show = False)
p2.append(p3[0])
p2.xlim = (-10,10)
p2.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### 2D parametric functions
#
# `plot_parametric` plots parametric functions.

# %%
t = sp.Symbol('t')
lissajou = sp.plot_parametric( sp.sin(3*t), 2*sp.sin(2*t), (t, -2*sp.pi, 2*sp.pi))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### 2D Implicit plots
#
# `plot_implicit` will plot curves or regions of the plane defined implicitely

# %%
(x,y) = sp.symbols( ('x', 'y') )
imp = sp.plot_implicit(sp.Eq(2*x**2 + y**2, 1), (x,-1.1,1.1), (y, -1.1,1.1), aspect_ratio = (1,1))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# plot the region between the curves y = x**2 and $y = sqrt(x)
sp.plot_implicit(sp.And(x**2+y**2 < 1, y<x**2), (x, -1.5, 1.5), (y, -1.5, 1.5), aspect_ratio = (1,1))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x = sp.Symbol('x')

f = sp.Function('f')(x)

m = sp.Integer(10)
k = sp.RealNumber(0.1)
dfeq = m*sp.diff(f,x,2)+k*f
dfeq
# Out:
# 0.1*f(x) + 10*Derivative(f(x), (x, 2))

# %%
import sympy as sp
# Define variables and function
t = sp.symbols('t')  # time
m = sp.symbols('m', positive=True) # mass
k = sp.symbols('k', positive=True) # spring constant
X = sp.Function('X')(t) # Position as a function of time

# Define the differential equation: m*x''(t) + k*x(t) = 0
diffeq = sp.Eq(m * X.diff(t, 2) + k * x, 0)

# Solve the ODE
general_sol = sp.dsolve(diffeq, X)
print("General Solution:")
print(general_sol)
# Out:
# General Solution:
# Eq(X(t), C1 + k*Integral(t*x(t), t)/m + t*(C2 - k*Integral(x(t), t)/m))

# %%
exact_eq = diffeq.subs([(m, 10),(k, 2)])
exact_sol = sp.dsolve(exact_eq, ics = {X.subs([(t,0)]) : 1, X.diff(t,1).subs([(t,0)]) : 2 })
print(exact_sol.simplify())
# Out:
# Eq(X(t), t*(-Integral(x(t), t) + Integral(x(t), (t, 0)) + 10)/5 + Integral(t*x(t), t)/5 - Integral(t*x(t), (t, 0))/5 + 1)

# %%
sol = sp.dsolve(dfeq)
sol
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 sol = sp.dsolve(dfeq)
#       2 sol
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/solvers/ode/ode.py:640, in dsolve(eq, func, hint, simplify, ics, xi, eta, x0, n, **kwargs)
#     637 else:
#     638     # The key 'hint' stores the hint needed to be solved for.
#     639     hint = hints['hint']
# --> 640     return _helper_simplify(eq, hint, hints, simplify, ics=ics)
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/solvers/ode/ode.py:668, in _helper_simplify(eq, hint, match, simplify, ics, **kwargs)
#     663 if simplify:
#     664     # odesimp() will attempt to integrate, if necessary, apply constantsimp(),
#     665     # attempt to solve for func, and apply any other hint specific
#     666     # simplifications
#     667     if isinstance(solvefunc, SingleODESolver):
# --> 668         sols = solvefunc.get_general_solution()
#     669     else:
#     670         sols = solvefunc(eq, func, order, match)
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/solvers/ode/single.py:283, in SingleODESolver.get_general_solution(self, simplify)
#     281     msg = "%s solver cannot solve:\n%s"
#     282     raise ODEMatchError(msg % (self.hint, self.ode_problem.eq))
# --> 283 return self._get_general_solution(simplify_flag=simplify)
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/solvers/ode/single.py:897, in Factorable._get_general_solution(self, simplify_flag)
#     895 for eq in eqns:
#     896     try:
# --> 897         sol = dsolve(eq, func(x))
#     898     except NotImplementedError:
#     899         continue
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/solvers/ode/ode.py:640, in dsolve(eq, func, hint, simplify, ics, xi, eta, x0, n, **kwargs)
#     637 else:
#     638     # The key 'hint' stores the hint needed to be solved for.
#     639     hint = hints['hint']
# --> 640     return _helper_simplify(eq, hint, hints, simplify, ics=ics)
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/solvers/ode/ode.py:668, in _helper_simplify(eq, hint, match, simplify, ics, **kwargs)
#     663 if simplify:
#     664     # odesimp() will attempt to integrate, if necessary, apply constantsimp(),
#     665     # attempt to solve for func, and apply any other hint specific
#     666     # simplifications
#     667     if isinstance(solvefunc, SingleODESolver):
# --> 668         sols = solvefunc.get_general_solution()
#     669     else:
#     670         sols = solvefunc(eq, func, order, match)
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/solvers/ode/single.py:283, in SingleODESolver.get_general_solution(self, simplify)
#     281     msg = "%s solver cannot solve:\n%s"
#     282     raise ODEMatchError(msg % (self.hint, self.ode_problem.eq))
# --> 283 return self._get_general_solution(simplify_flag=simplify)
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/solvers/ode/single.py:897, in Factorable._get_general_solution(self, simplify_flag)
#     895 for eq in eqns:
#     896     try:
# --> 897         sol = dsolve(eq, func(x))
#     898     except NotImplementedError:
#     899         continue
#
#     [... skipping similar frames: Factorable._get_general_solution at line 897 (734 times), _helper_simplify at line 668 (734 times), dsolve at line 640 (734 times), SingleODESolver.get_general_solution at line 283 (734 times)]
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/solvers/ode/ode.py:640, in dsolve(eq, func, hint, simplify, ics, xi, eta, x0, n, **kwargs)
#     637 else:
#     638     # The key 'hint' stores the hint needed to be solved for.
#     639     hint = hints['hint']
# --> 640     return _helper_simplify(eq, hint, hints, simplify, ics=ics)
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/solvers/ode/ode.py:668, in _helper_simplify(eq, hint, match, simplify, ics, **kwargs)
#     663 if simplify:
#     664     # odesimp() will attempt to integrate, if necessary, apply constantsimp(),
#     665     # attempt to solve for func, and apply any other hint specific
#     666     # simplifications
#     667     if isinstance(solvefunc, SingleODESolver):
# --> 668         sols = solvefunc.get_general_solution()
#     669     else:
#     670         sols = solvefunc(eq, func, order, match)
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/solvers/ode/single.py:283, in SingleODESolver.get_general_solution(self, simplify)
#     281     msg = "%s solver cannot solve:\n%s"
#     282     raise ODEMatchError(msg % (self.hint, self.ode_problem.eq))
# --> 283 return self._get_general_solution(simplify_flag=simplify)
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/solvers/ode/single.py:897, in Factorable._get_general_solution(self, simplify_flag)
#     895 for eq in eqns:
#     896     try:
# --> 897         sol = dsolve(eq, func(x))
#     898     except NotImplementedError:
#     899         continue
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/solvers/ode/ode.py:605, in dsolve(eq, func, hint, simplify, ics, xi, eta, x0, n, **kwargs)
#     602 given_hint = hint  # hint given by the user
#     604 # See the docstring of _desolve for more details.
# --> 605 hints = _desolve(eq, func=func,
#     606     hint=hint, simplify=True, xi=xi, eta=eta, type='ode', ics=ics,
#     607     x0=x0, n=n, **kwargs)
#     608 eq = hints.pop('eq', eq)
#     609 all_ = hints.pop('all', False)
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/solvers/deutils.py:209, in _desolve(eq, func, hint, ics, simplify, prep, **kwargs)
#     205 # Magic that should only be used internally.  Prevents classify_ode from
#     206 # being called more than it needs to be by passing its results through
#     207 # recursive calls.
#     208 if kwargs.get('classify', True):
# --> 209     hints = classifier(eq, func, dict=True, ics=ics, xi=xi, eta=eta,
#     210     n=terms, x0=x0, hint=hint, prep=prep)
#     212 else:
#     213     # Here is what all this means:
#     214     #
#    (...)    223     #          hint.
#     224     # order:   The order of the DE, as determined by ode_order().
#     225     hints = kwargs.get('hint',
#     226                        {'default': hint,
#     227                         hint: kwargs['match'],
#     228                         'order': kwargs['order']})
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/solvers/ode/ode.py:1039, in classify_ode(eq, func, dict, ics, prep, xi, eta, n, **kwargs)
#    1037 for hint in user_map:
#    1038     solver = user_map[hint](ode)
# -> 1039     if solver.matches():
#    1040         matching_hints[hint] = solver
#    1041         if user_map[hint].has_integral:
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/solvers/ode/single.py:276, in SingleODESolver.matches(self)
#     273     return self._matched
#     275 if self._matched is None:
# --> 276     self._matched = self._matches()
#     277 return self._matched
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/solvers/ode/single.py:870, in Factorable._matches(self)
#     868 self.eqs = []
#     869 eq = eq_orig.collect(f(x), func = cancel)
# --> 870 eq = fraction(factor(eq))[0]
#     871 factors = Mul.make_args(factor(eq))
#     872 roots = [fac.as_base_exp() for fac in factors if len(fac.args)!=0]
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/polys/polytools.py:6735, in factor(f, deep, *gens, **args)
#    6732     return f.xreplace(partials)
#    6734 try:
# -> 6735     return _generic_factor(f, gens, args, method='factor')
#    6736 except PolynomialError:
#    6737     if not f.is_commutative:
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/polys/polytools.py:6416, in _generic_factor(expr, gens, args, method)
#    6414 opt = options.build_options(gens, args)
#    6415 opt['fraction'] = fraction
# -> 6416 return _symbolic_factor(sympify(expr), opt, method)
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/polys/polytools.py:6356, in _symbolic_factor(expr, opt, method)
#    6354     if hasattr(expr,'_eval_factor'):
#    6355         return expr._eval_factor()
# -> 6356     coeff, factors = _symbolic_factor_list(together(expr, fraction=opt['fraction']), opt, method)
#    6357     return _keep_coeff(coeff, _factors_product(factors))
#    6358 elif hasattr(expr, 'args'):
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/polys/rationaltools.py:85, in together(expr, deep, fraction)
#      81         return expr.__class__([ _together(ex) for ex in expr ])
#      83     return expr
# ---> 85 return _together(sympify(expr))
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/polys/rationaltools.py:68, in together.<locals>._together(expr)
#      66     return expr
#      67 elif expr.is_Add:
# ---> 68     return gcd_terms(list(map(_together, Add.make_args(expr))), fraction=fraction)
#      69 elif expr.is_Pow:
#      70     base = _together(expr.base)
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/core/exprtools.py:1072, in gcd_terms(terms, isprimitive, clear, fraction)
#    1070     terms = sympify(terms)
#    1071 terms, reps = mask(terms)
# -> 1072 cont, numer, denom = _gcd_terms(terms, isprimitive, fraction)
#    1073 numer = numer.xreplace(reps)
#    1074 coeff, factors = cont.as_coeff_Mul()
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/core/exprtools.py:957, in _gcd_terms(terms, isprimitive, fraction)
#     954     cont = cont.gcd(term)
#     956 for i, term in enumerate(terms):
# --> 957     terms[i] = term.quo(cont)
#     959 if fraction:
#     960     denom = terms[0].denom
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/core/exprtools.py:872, in Term.quo(self, other)
#     871 def quo(self, other):  # Term
# --> 872     return self.mul(other.inv())
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/core/exprtools.py:861, in Term.mul(self, other)
#     859 def mul(self, other):  # Term
#     860     coeff = self.coeff*other.coeff
# --> 861     numer = self.numer.mul(other.numer)
#     862     denom = self.denom.mul(other.denom)
#     864     numer, denom = numer.normal(denom)
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/core/exprtools.py:488, in Factors.mul(self, other)
#     484             continue
#     486     factors[factor] = exp
# --> 488 return Factors(factors)
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/core/exprtools.py:328, in Factors.__init__(self, factors)
#     326 if isinstance(factors, Factors):
#     327     factors = factors.factors.copy()
# --> 328 elif factors in (None, S.One):
#     329     factors = {}
#     330 elif factors is S.Zero or factors == 0:
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/core/numbers.py:1970, in Integer.__eq__(self, other)
#    1968 elif isinstance(other, Integer):
#    1969     return (self.p == other.p)
# -> 1970 return Rational.__eq__(self, other)
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/core/numbers.py:1624, in Rational.__eq__(self, other)
#    1622 def __eq__(self, other):
#    1623     try:
# -> 1624         other = _sympify(other)
#    1625     except SympifyError:
#    1626         return NotImplemented
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/core/sympify.py:540, in _sympify(a)
#     514 def _sympify(a):
#     515     """
#     516     Short version of :func:`~.sympify` for internal usage for ``__add__`` and
#     517     ``__eq__`` methods where it is ok to allow some things (like Python
#    (...)    538
#     539     """
# --> 540     return sympify(a, strict=True)
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/core/sympify.py:422, in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     420         conv = _sympy_converter.get(superclass)
#     421     if conv is not None:
# --> 422         return conv(a)
#     424 if cls is type(None):
#     425     if strict:
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/core/containers.py:337, in <lambda>(d)
#     334     __hash__ : Callable[[Basic], Any] = Basic.__hash__
#     336 # this handles dict, defaultdict, OrderedDict
# --> 337 _sympy_converter[dict] = lambda d: Dict(*d.items())
#     339 class OrderedSet(MutableSet):
#     340     def __init__(self, iterable=None):
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/core/containers.py:268, in Dict.__new__(cls, *args)
#     266     raise TypeError('Pass Dict args as Dict((k1, v1), ...) or Dict({k1: v1, ...})')
#     267 elements = frozenset(items)
# --> 268 obj = Basic.__new__(cls, *ordered(items))
#     269 obj.elements = elements
#     270 obj._dict = dict(items)  # In case Tuple decides it wants to sympify
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/core/sorting.py:312, in ordered(seq, keys, default, warn)
#     309         if len(u) > 1:
#     310             raise ValueError(
#     311                 'not enough keys to break ties: %s' % u)
# --> 312 yield from value
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/core/sorting.py:294, in ordered(seq, keys, default, warn)
#     292         keys = []
#     293     for a in seq:
# --> 294         d[f(a)].append(a)
#     295 else:
#     296     if not default:
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/core/sorting.py:193, in _nodes(e)
#     190     if isinstance(e, Derivative):
#     191         return _nodes(e.expr) + sum(i[1] if i[1].is_Number else
#     192             _nodes(i[1]) for i in e.variable_count)
# --> 193     return _node_count(e)
#     194 elif iterable(e):
#     195     return 1 + sum(_nodes(ei) for ei in e)
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/core/sorting.py:176, in _node_count(e)
#     174 if e.is_Float:
#     175     return 0.5
# --> 176 return 1 + sum(map(_node_count, e.args))
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/core/sorting.py:176, in _node_count(e)
#     174 if e.is_Float:
#     175     return 0.5
# --> 176 return 1 + sum(map(_node_count, e.args))
#
#     [... skipping similar frames: _node_count at line 176 (1 times)]
#
# File /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages/sympy/core/sorting.py:176, in _node_count(e)
#     174 if e.is_Float:
#     175     return 0.5
# --> 176 return 1 + sum(map(_node_count, e.args))
#
# RecursionError: maximum recursion depth exceeded

# %%
x = sp.Symbol('x')
y = sp.Symbol('y')
z = sp.Symbol('z')
f = sp.Function('f')(x,y)

dfeq = sp.Eq(lhs = sp.diff(f,x)+sp.diff(f,y),rhs = 0)

dfeq
# Out:
# Eq(Derivative(f(x, y), x) + Derivative(f(x, y), y), 0)

# %%
sol = sp.pdsolve(dfeq)

sol
# Out:
# Eq(f(x, y), F(x - y))
