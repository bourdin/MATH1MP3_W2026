# %%
import pandas as pd

gp = pd.read_csv("1810000101_databaseLoadingData.csv", skipinitialspace=True)
gp

# %%
places = gp['GEO']
places.unique()

# %%
gpGTA = gp[gp['GEO'] == 'Toronto, Ontario']
gpGTA
gpGTA['REF_DATE'].unique()

# %%
year = [date[:4] for date in gpGTA['REF_DATE']]
gpGTA['year'] = year

# %%
gpGTA[ ['VALUE', 'year'] ].groupby('year').mean()
