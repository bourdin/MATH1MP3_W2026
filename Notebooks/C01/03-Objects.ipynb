# %%
a = "12 + 4"
a = '12 + 4'
print(a)

# %% [markdown]
# ## Strings again
# ### String indexing
# It is possible to extract parts of a string, using *indexing*, denoted using square brackets '[]'.
# * `s[0]` is the first character in `s`, `s[1]` the second etc.
# * `s[-1]` is the last character in `s`, `s[-2]`, second to last etc
#
# Note that in python, indices start from 0, so the valid range of indices for a string of length $n$ is $0$ to $n-1$.
#
# The function `len` can be used to query the length of a given string

# %%
s = 'test string'
print('s:    ', s)
print('len(s): ', len(s))
print('s[0]: ',s[0])
print(type(s[0]))
print('s[1]: ', s[1])
print('s[-1]: ', s[-1])

# %% [markdown]
# # Announcements
#
# - Assignment 1 due Wednesday at 11:59pm
# - Office hours moved! Now, Mon 10am-11am and Wed 1pm-2pm in HH 401
# - Online webinar on floating point vs reals see Avenue

# %%
a = 105.0
a**1024

# %% [markdown]
# # Last time
#
# ### Floating point numbers revisited
# - The two types of floating point errors.
# - Order of operations matters!
# - Equality of floating points is a flawed notion of equality.
# - Errors can have undesirable effects especially when working with infinity i.e. applications in calculus.

# %% [markdown]
# # Exercise - solving the quadratic equation
#
# We know that we can use the quadratic formula to find roots of any polynomial of the form
#
# $$f(x) = ax^2+bx+c$$
#
# Let $\Delta = \sqrt{b^2-4ac}$. We call $\Delta$ the *discriminant*. Then, the quadratic formula, tells us that $f(x)$ has a pair of roots of the form,
#
# $$x_1 = \frac{-b +\Delta}{2a}$$
# $$x_2 = \frac{-b-\Delta}{2a}$$
#
# Use Python's math library to implement the quadratic formula.

# %%
import math
a = 1
b = 2
c = 3
# compute the roots of the polynomial ax^2 + bx + c
discriminant = math.sqrt(b**2 -4*a*c)
print("The first root of the polynomial is:",(-b+discriminant)/(2*a))
print("The second root of the polynomial is:",(-b-discriminant)/(2*a))

# %% [markdown]
# ### Today: Python's remaining base types - Containers
#
# The first container type we see are strings!

# %%
s = 'test string'
print('s:    ', s)
print('s[-1]: ', s[-1])
print('s[-1]: ', s[-2])
print('s[0]: ',s[0])

# %% [markdown]
# Recall, we have previously discussed how strings are a homogeneous container. That is, any object within the string will also have type string.

# %%
# an example
s = '12abc'
print(type(s[0]))
print(type(s[3]))

# %% [markdown]
# However, Python does still "know" that these objects have different type.

# %%
# this works
print(int(s[0]))

# %%
# but this doesn't
print(int(s[3]))

# %% [markdown]
# ### A common error
#
# The statement `s[i]` asks Python to fetch the value that lives at index `i` in the string container. It is assumed that this index is a valid one, that is, one that lives within the container. If it isn't, we will get an error.

# %%
s = 'a longer string'
print(len(s))

# %%
# this is fine
print(s[14])

# %%
# but this is not
print(s[15])

# %% [markdown]
# Indexing can be used to extract part of a string. Given a string `s`, `s[a:b]` denotes the string consistings of characters at position `a` to `b` (excluded).
#
# `len(s)` return the length of `s`, i.e. number of characters in `s`

# %%
print(s)
print('s[0:3]:  ', s[0:3])
print('s[3:-1]: ', s[3:-1])
print(len(s))

# %% [markdown]
# If `a` is omitted, `s[:b]` is to be understood as all positions up to (excluding) `b`.
# If `b` is omitted, `s[a:]` is to be understood as all starting with `a`.

# %%
print('s[:3]: ',s[:3])
print('s[:3]: ',s[0:3])
print('s[3:]: ',s[3:])
print(s[len(s)-1])

# %% [markdown]
# Optionally, one can also specify a stride: `s[a:b:c]` is a string containing characters at indices `a`, `a+c`, `a+2*c`, ... `b` in `s`.

# %%
numbers = '0123456789'
print(numbers)
print('numbers[0:10:2]: ', numbers[0:10:2])
print('numbers[1:10:2]: ', numbers[1:10:2])
print('numbers[1:10:3]: ', numbers[1:10:3])

# %% [markdown]
# Note that the stride can be negative, in which case one needs to get `a>b`

# %%
print('numbers[10:0:-1]: ', numbers[10:0:-1])

# %% [markdown]
# Note that the rules for omitted bounds still apply when a stride is specified:

# %%
print('numbers[0:10:2]: ', numbers[0:10:2])
print('numbers[:10:2]:  ', numbers[:10:2])
print('numbers[::2]:    ', numbers[0::2])

# %% [markdown]
# ### A classical example: reversing a string.

# %%
# Using string slicing reverse the following string
s = 'a string to be reversed'
# try out your code here!
print(s[::-1])

# %%
x = 1 # x has value 1
x += 1 # x has value 2

# %% [markdown]
# ### Important:
# Python strings are *immutable*. This means that it is not possible to use indexing to modify a string.

# %%
msg = "this is a test"
# You cannot capitalize the first character this way;
msg[0] = "T"

# %% [markdown]
# ## 1.2 F-string
#
# Formatted strings are incredibly handy for returning nicely *formatted* output to the user. We declare a formatted string by placing an `f` before the first string delimeter.

# %%
n = 7
animal = 'dog'
print('A animal year is worth n human years')
print(f'A {animal} year is worth {n} human years')

# %% [markdown]
# Format has many other useful functions, most of which we will not use regularly.

# %%
n = 128512
print(f'Here is a number in base 10, {n}.')
print(f'Here is that same number in binary, {n:b}')
print(f'Here is the unicode character corresponding to {n}: {n:c}')

# %%
's'
1

# %% [markdown]
# # Monday January 19th 2026
#
# ## Announcements
# - First midterm Feb. 3rd 7:00pm-9:00pm in PGCLL/B138. Please contact me if you have tech questions!
#
# # Last time - Strings: Indexing, slicing, and methods
# - Strings in Python are
#     - **ordered** (they support indexing and slicing syntax)
#     - **homogeneous** (every substring is a string!)
#     - **containers** (they exist within a broader class of types called containers. More on that today...)
#     - **immutable** (we cannot change an entry at a certain index by using an update statement)
# - We saw a special Python tool for dealing with strings called **f-strings**. By starting a string with an `f`, i.e. `f"string"`, we can insert the values of variables into our strings. That is, if `n` has value `5`, then the statement `"{n}"` has value `"{n}"`, but the statement `f"{n}"` has value `"5"`.
# - We started talking about the design philosophy behind Python. We said that Python is an **object oriented programming language**. This means that many of the built-in functions are attached to certain types. Functions which are only implemented for certain types are called **methods**. Unlike normal function application, of the form `print(x)`, we call a method in the following way `x.name_of_method()`, where `x` has the required type.
# - We saw some examples of methods for strings, such as:
#     - `upper()`
#     - `lower()`
#     - `swapcase()`
# - If you ever forget the names of methods for a certain type, a helpful function is `dir()`, which will give some of the names of method implemented on the type. For a complete list visit the Python documentation.
# - **Important Note:** If you don't know what a certain method does, try it out! Clicking run on a Python program will rarely end in catastrophe!# Thursday Jan. 15th 2026

# %%
s = "A test string"

# %%
s[0]

# %%
s[-1]

# %%
s[1::2]

# %%
s[0] = 'a' # update

# %%
s = "This is a number, 1"
print(type(s[-1]))

# %%
s.lower()

# %% [markdown]
# ## Objects and methods
# Python 'objects' are more than different 'types'. In particular object *encapsulate* 'data' and 'methods'. You can think of the data, as the 'value' of a string. Methods are operation that are applied to the data or properties of that data.
#
# The `dir` command will print all methods implemented for a object.

# %%
msg = "this is a test"
print(msg.upper())

1 + 2
1. + 2.

# %%
s = '1,2,3'
dir(s)

# %%
1+2

# %% [markdown]
# ### Playing with string methods

# %%
s = 'a Test String'
print(s.upper())
print(s.lower())
print(s.swapcase())

# %% [markdown]
# ### Note - Double underscores
#
# When calling the `dir()` function on an object, you can see the methods that are implemented for this type. Some of these methods are written with names of the form `__add__` or `__mul__`. This special notation is for methods that are shared between multiple types with different implementations, and for which there is a shortened syntax. That is, any type that implements the `__add__` method is able to use `+` as notation for this function.

# %% [markdown]
# # This time - Containers
# This time we will introduce the remaining container types

# %% [markdown]
# ## Containers
# Strings are just examples of a bigger concept: *containers*. Containers contain stuff. They share methods to refer to some of their content, or perform operations on them.
# Typical operations are
# * indexing `x[i]`
# * query `'M' in '1MP3'`
# * extension, concatenation, restriction, ...

# %% [markdown]
# ### Lists
#
# A *list* is an *ordered* collection of objects (i.e. `[1,2]` and `[2,1]` are not equal).
#
# * Lists are defined using square brackets ('[]') or the `list()` operator.
# * Lists can be indexed.
# * List are mutable

# %%
l = [0,1,2,3,4,5,6]
print(l)
print(len(l))
print(l[0])
print(l[-1])
print(l[0:4])

# %%
l = [0,1,2,3,4,5,6]
print('l:      ', l)
print('l[0]:   ', l[0])
print('l[1:3]: ', l[1:3])
print('l[::-2]: ', l[::-2])

# %%
s = "1,2,3,4"
s[-1] = "5"

# %%
s = [1,2,3,4]
print(s)
s[-1] = 5
print(s)

# %% [markdown]
# Another unusual feature of python is that not all elements in a list must be the same type of objects:

# %%
l = [1, 'two', 3+4j, [5,6,7]]
print(l)

# %%
type(l[0])
type(l[1])
type(l[-1])

# %% [markdown]
# Unlike with strings, in the statement above `l[0]` will have type `int` and `l[1]` will have type `str`.

# %%
l[0] = -1
print(l)

# %% [markdown]
# **Notice** In the above example `l` contains as an element, another list. We call lists that contain other lists, *nested lists*. We will commonly represent matrices as netsed lists.

# %%
l = [[1,2,3],[4,5,6]]
len(l)
print(l[0])
print(l[1])
print(l[0][1])

# %% [markdown]
# #### list methods
# `count`, `sort`, `append`, `reverse`, `extend`, ... (see `dir(list())` for a long list)

# %%
l1 = [1,2,3]
l2 = [4,5,6]
l1 + l2
l1.append(4)
l1.extend([5,6])

# %%
print(l1)

# %% [markdown]
# ### Python lists are not regular "lists"
# Lists in Python can be thought of as a hybrid between a classical list from other programming languages (usually called a *linked list*) and an array. Python lists are more like arrays in that we can search for items by their index, this is much quicker than in a linked list. Python lists are like linked lists, in that they can contain objects of any data type (arrays are usually homogeneous).

# %% [markdown]
# # Exercise - 2 by 2 derivatives
#
# We can represent matrices in Python with nested lists. That is, the matrix
# $$\begin{bmatrix}
# 1 & 2 & 3\\
# 4 & 5 & 6\\
# 7 & 8 & 9
# \end{bmatrix}$$
# can be represented by the nested list `[[1,2,3],[4,5,6],[7,8,9]]`.
#
# Using this representation, write code that computes the determinant of a 2 by 2 matrix represented as a nested list. **Recall:** Given a 2 by 2 matrix of the following form,
# $$\begin{bmatrix}
# a & b\\ c & d
# \end{bmatrix}$$
# the determinant can be computed as $ad-bc$.

# %%
# here is a 2 by 2 matrix
m = [[1,2],[3,4]]
# write code to compute its determinant!
print(m[0][0])
print(m[1][1])
print(m[0][0]*m[1][1] - m[0][1]*m[1][0]) # formula for 2 by 2 determinant

# %% [markdown]
# # Exercise - 3 by 3 trace
#
# Recall that the trace of a matrix is the sum of its diagonal entries. That is, for the following matrix
# $$\begin{bmatrix} 1 & 2  & 3 \\ 4 & 5 & 6\\ 7 & 8 & 9\end{bmatrix}$$
# the trace can be computed as $1+ 5+ 9=14$. Write code to compute the trace of the following 3 by 3 matrix.

# %%
# here is a 3 by 3 matrix
m = [[1,-1,4],[10,1000,10000],[0,0,0]]
# write code to compute its trace!
m[0][0]+m[1][1]+m[2][2]
# for an n by n
# m[0][0] + m[1][1] + ... + m[-1][-1]

# %% [markdown]
# ### Tuples
#
# `tuples` are pretty much like lists except that they are immutable. They use regular parentheses `()`.

# %%
t = (1,2,'three')
print(t[1])

# %%
s = [1,2,'three']
s[2] = 'two'
print(s)

# %%
t[2] = -1

# %% [markdown]
# Tuples in Python serve the purpose of *packing* and *unpacking* data.

# %%
# here is some data to be packaged
x1 = 1
x2 = 6.7
x3 = 'a string to store'

# %%
# packaging the above data in a tuple
t = (x1, x2, x3)
t[0]

# %%
# unpacking t
x1, x2, x3 = t
print(x1)

# %% [markdown]
# ## Tuples vs Lists
#
# At face value tuples and lists seems quite similar. However, there are some key differnces to remember.
# - Lists are mutable tuples are immutable
# - Lists have dynamic size tuples have a fixed size
# - Different use cases: Tuples are for packaging data that will not change. Lists are more dynamic.

# %% [markdown]
# ### Sets
# Sets are unordered (just like in math) so they cannot be indexed.

# %%
s = {1,2,3}
print(s)
s = {'blue','a string', 5}
print(s)

# %%
new_set = {4,3,0,1}
print(new_set)

# %%
new_new_set = {9,8,1,2,'a','b'}
print(new_new_set)
print(hash(9))

# %%
L = [1,'c',3, 'a','b',2]
s = {1,2,3,'a','b','c'}
2 in L
2 in s

# %%
s1 = set([1,2,3,4])
s2 = {'red', 'white', 2}

print('Union:        ', s1 | s2) # in CS, '|' often denotes logical 'or'. One could also write si.union(s2) 
print('Intersection: ', s1 & s2) # '&' denotes 'and' 
print(2 in s1)

print('s1 is ',s1)
# Can you explain why the following commands produce different results?
s1.add(3)
print('s1 is now ',s1)

s1.add('3')
print('s1 is now ',s1)

# %%
s1[1]

# %% [markdown]
# A lack of indexing capability may seem like a drawback of Sets. However, this turns out to be their biggest strength. Below, try to creating some sets and guess what order Python will store elements in. It turns out that this default ordering gains us lots of efficiency for a specific operation called a lookup, i.e. questions of the form is `1` in `S`?

# %%
# create some sets here

# in what order will the elements be stored?

# %% [markdown]
# # Tuesday Jan 20th 2026
#
# # Last time - Lists and Tuples
# - Lists are created with square brackets, i.e. `[1,2,3]` is a three-element list.

# %%
# this is a list
L = [1,2,3]
# and so is this (this is called a nested list!)
L2 = [1,2,'string',['another','list']]

# %% [markdown]
# - The above list contains objects of different types. This tells us that lists are heterogeneous data types.
# - **Question:** What may be some advantages and disadvantages of have heterogeneous vs homogeneous container types?

# %%
# commonly we use nested lists to represent matrices!
m = [[1,2],[3,4]]
# we can use nested indexing on nested lists
# what should this command return?
print(m[0][0])
# Out:
# 1

# %% [markdown]
# - Lists are a container type so they have a length (the `len` function will tell us the length of a list); they can be indexed; and they support questions of the form "is the object `v` an element of the list `L`?"

# %%
# the length of a list is the number of elements it has
print(f"The length of L is {len(L)}")
# Careful! 
# The length of a nested list can sometimes surprise us!
print(f"The length of m is {len(m)}")
# Out:
# The length of L is 3
# The length of m is 2

# %% [markdown]
# - Lists are **mutable**, that is the values they contain may be updated with an assignment statement.

# %%
print(L)
L[0] = 'new element'
print(L)
# Out:
# [1, 2, 3]
# ['new element', 2, 3]

# %% [markdown]
# - **Important Note:** Lists are sometimes *too* mutable. Consider the following example.

# %%
L = [1,2,3]
M = L
print(f"L = {L} and M = {M}")
L[0] = 5
print(f"L = {L} and M = {M}")
# Out:
# L = [1, 2, 3] and M = [1, 2, 3]
# L = [5, 2, 3] and M = [5, 2, 3]

# %%
# a workaround for this
# using a list method
L = [1,2,3]
M = L.copy() 
print(f"L = {L} and M = {M}")
L[0] = 5
print(f"L = {L} and M = {M}")
# Out:
# L = [1, 2, 3] and M = [1, 2, 3]
# L = [5, 2, 3] and M = [1, 2, 3]

# %%
# or using the list constructor
L = [1,2,3]
M = list(L)
print(f"L = {L} and M = {M}")
L[0] = 5
print(f"L = {L} and M = {M}")
# Out:
# L = [1, 2, 3] and M = [1, 2, 3]
# L = [5, 2, 3] and M = [1, 2, 3]

# %%
# even more troubling
L = [1,2,[1,2,3]]
#M = list(L)
M = L.copy()
print(f"L = {L} and M = {M}")
L[2][0] = 5
print(f"L = {L} and M = {M}")
# Out:
# L = [1, 2, [1, 2, 3]] and M = [1, 2, [1, 2, 3]]
# L = [1, 2, [5, 2, 3]] and M = [1, 2, [5, 2, 3]]

# %%
# a workaround 
import copy
L = [1,2,[1,2,3]]
M = copy.deepcopy(L)
print(f"L = {L} and M = {M}")
L[2][0] = 5
print(f"L = {L} and M = {M}")
# Out:
# L = [1, 2, [1, 2, 3]] and M = [1, 2, [1, 2, 3]]
# L = [1, 2, [5, 2, 3]] and M = [1, 2, [1, 2, 3]]

# %% [markdown]
# **Question:** Why does this occur?

# %% [markdown]
# - Tuples are created with round brackets or simply by separating values with commas

# %%
# this is a tuple 
t = (1,2,3)
# and so is this
t1 = 1,2,3

# %% [markdown]
# - Tuples are also heterogeneous

# %%
t = (1,2,'string',[1,2,3])

# %% [markdown]
# - Like other container types, tuples have a length; support indexing syntax; and support questions of the form "is the value `v` in the tuple `t`?"

# %%
print(f"t has length {len(t)}")
print(f"t[0] has value {t[0]}")
print(f"The statement '2 is in t' is {2 in t},")
print(f"but the statement '3 is in t' is {3 in t[3]}.")
# Out:
# t has length 4
# t[0] has value 1
# The statement '2 is in t' is True,
# but the statement '3 is in t' is True.

# %% [markdown]
# - Unlike lists tuples are **immutable** (they are made to statically hold data, not to change dynamically)

# %%
# this will result in an error
t[0] = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 2
#       1 # this will result in an error
# ----> 2 t[0] = 1
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# - Tuples support a special syntax called *packing* and *unpacking*

# %%
# here are some values
x = 2
y = 1 + 1j
z = 'a longer string'
# here we can pack them in a tuple
t = (x,y,z)
print(t)
# Out:
# (2, (1+1j), 'a longer string')

# %%
# we can then unpack them again
# note ORDER MATTERS
a,b,c = t
print(z)
# Out:
# a longer string

# %% [markdown]
# # Exercise - Swap the values of the variables x and y

# %%
# consider the following variables
x = 1
y = 2
# write code that swaps their values
tmp = x
x = y
y = tmp
# hint 1 - use a third "temporary" variable
# hint 2 - use tuple packing and unpacking
x,y = y,x
# (2,1)
# x = 2
# y = 1

# %% [markdown]
# - Sets can be created with curly brackets

# %%
# this is a set
s = {1,2,3,'string'}
print(s)
print(len(s))
print(1 in s)
# Out:
# {1, 2, 3, 'string'}
# 4
# True

# %% [markdown]
# - Sets share some commonalities with the other container types we have seen:
#     - They are heterogeneous
#     - They have a length
#     - The support questions of the form "is x in the set s?" (They are quite good for this purpose!)
# - However, sets do not support indexing as they are "unordered" (sort of).

# %%
# even though sets are heterogeneous,
# there is one type we have seen so far that 
# they cannot contain. Try to find it
s = {1,2,[3,4]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 4
#       1 # even though sets are heterogeneous,
#       2 # there is one type we have seen so far that
#       3 # they cannot contain. Try to find it
# ----> 4 s = {1,2,[3,4]}
#
# TypeError: unhashable type: 'list'

# %%
# why can't sets contain this type?

# %%
print(f"The length of s is {len(s)}.")
print(f"The statement '2 is in s' is {2 in s},")
print(f"but the statement '7.2 in s' is {7.2 in s}.")
# Out:
# The length of s is 2.
# The statement '2 is in s' is True,
# but the statement '7.2 in s' is False.

# %%
# this will return an error
print(s[1])

# %% [markdown]
# - Sets are mutable, but only under methods since they don't support indexing

# %%
print(s)
s.add(7)
s.add(3)
print(s)
s.discard(3)
print(s)
# Out:
# {1, 2, 7}
# {1, 2, 3, 7}
# {1, 2, 7}

# %%
print({1,2,2,2,2,3})
L = [9,9,9,1,2,2,2,4,4,5]
s = set(L)
L_no_repeats = list(s)
print(L_no_repeats)
# Out:
# {1, 2, 3}
# [1, 2, 4, 5, 9]

# %%
# what kind of object is the following?
s = {}
print(type(s))
# Out:
# <class 'dict'>

# %% [markdown]
# ### Dictionaries
#
# Dictionaries are a convenient way to store *structured* data.
# They can be thought of as (unordered) lists whose indexes can be any object (hence do not have a canonical ordering but must be unique), or as collections of pairs `(key:value)`.
# Dictionaries use curly brackets `{}`

# %%
d = {'a':1, 'b':2, 'c':3}
print('d: ', d)
print("d['a']: ", d['a'])
# Out:
# d:  {'a': 1, 'b': 2, 'c': 3}
# d['a']:  1

# %%
d = {0 : 1, 1:2, 2:3}
L = [1,2,3]
print(d[0])
print(L[0])
# Out:
# 1
# 1

# %% [markdown]
# The values of a dictionary can be any Python object. The keys can be any *immutable* Python object (it wouldn't be a good idea if the key to a certain value could be changed arbitrarily.)

# %%
d2 = {1:'abc', (0,1):[1,2,3]}
print(d2[1])
print(d2[(0,1)])
# Out:
# abc
# [1, 2, 3]

# %%
d3 = {[1,2]:1}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 d3 = {[1,2]:1}
#
# TypeError: unhashable type: 'list'

# %%
d4 = {'a':1,'a':2}
print(d4)
# Out:
# {'a': 2}

# %% [markdown]
# Some dictionary methods:
#  * `keys`, `values`
#  * `pop`
#  * `update`

# %%
d = {'a':1, 'b': 2,'c':3}
print(d.values())
# Out:
# dict_values([1, 2, 3])

# %%
d3 = {}
d3.update(d)
print(d3)
d3.update(d2)
print(d3)
# Out:
# {'a': 1, 'b': 2, 'c': 3}
# {'a': 1, 'b': 2, 'c': 3, 1: 'abc', (0, 1): [1, 2, 3]}

# %% [markdown]
# ## Files
#
# Files are kind of like containers in that they "contain" information. Technically, a `file` object does not really contain the information but it provides methods and functionality to interface with system files...

# %%
f = open('example.txt','w')
f.write('The quick brown fox jumps over the lazy dog\n')
f.write('a man a plan a canal panama')
f.close()

# %%
f2 = open('example.txt')
s = f2.read()
f2.close
print(s)
# Out:
# The quick brown fox jumps over the lazy dog
# a man a plan a canal panama

# %%
f2 = open('example.txt')
s = f2.readlines()
f2.close
print(s)
# Out:
# ['The quick brown fox jumps over the lazy dog\n', 'a man a plan a canal panama']

# %%
f2 = open('example.txt')
print('line 1: ',f2.readline())
print('line 2: ',f2.readline())
print('line 3: ',f2.readline())
f2.close()

# Project Gutenberg
# Out:
# line 1:  The quick brown fox jumps over the lazy dog
#
# line 2:  a man a plan a canal panama
# line 3:
