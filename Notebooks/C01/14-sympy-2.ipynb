# %%
# %matplotlib widget
import matplotlib.pyplot as plt
import numpy as np
import sympy as sp

# %% [markdown]
# # 18-2 sympy continued
#
# ## Solving equations:
#
# Since `=` and `==` are already taken by python, an equation is declared as `Eq(lhs =  ..., rhs = ...)`. By default every expression is an equation (equal to zero).

# %%
(x, y, z) = sp.symbols( ('x', 'y', 'z') )
eq1 = sp.Eq(lhs = x*y + x - 3 + 2*x**2 - z*x**2 + x**3, rhs = 0)
eq1
# Out:
# Eq(x**3 - x**2*z + 2*x**2 + x*y + x - 3, 0)

# %%
help(sp.solveset)
# Out:
# Help on function solveset in module sympy.solvers.solveset:
#
# solveset(f, symbol=None, domain=Complexes)
#     Solves a given inequality or equation with set as output
#
#     Parameters
#     ==========
#
#     f : Expr or a relational.
#         The target equation or inequality
#     symbol : Symbol
#         The variable for which the equation is solved
#     domain : Set
#         The domain over which the equation is solved
#
#     Returns
#     =======
#
#     Set
#         A set of values for `symbol` for which `f` is True or is equal to
#         zero. An :class:`~.EmptySet` is returned if `f` is False or nonzero.
#         A :class:`~.ConditionSet` is returned as unsolved object if algorithms
#         to evaluate complete solution are not yet implemented.
#
#     ``solveset`` claims to be complete in the solution set that it returns.
#
#     Raises
#     ======
#
#     NotImplementedError
#         The algorithms to solve inequalities in complex domain  are
#         not yet implemented.
#     ValueError
#         The input is not valid.
#     RuntimeError
#         It is a bug, please report to the github issue tracker.
#
#
#     Notes
#     =====
#
#     Python interprets 0 and 1 as False and True, respectively, but
#     in this function they refer to solutions of an expression. So 0 and 1
#     return the domain and EmptySet, respectively, while True and False
#     return the opposite (as they are assumed to be solutions of relational
#     expressions).
#
#
#     See Also
#     ========
#
#     solveset_real: solver for real domain
#     solveset_complex: solver for complex domain
#
#     Examples
#     ========
#
#     >>> from sympy import exp, sin, Symbol, pprint, S, Eq
#     >>> from sympy.solvers.solveset import solveset, solveset_real
#
#     * The default domain is complex. Not specifying a domain will lead
#       to the solving of the equation in the complex domain (and this
#       is not affected by the assumptions on the symbol):
#
#     >>> x = Symbol('x')
#     >>> pprint(solveset(exp(x) - 1, x), use_unicode=False)
#     {2*n*I*pi | n in Integers}
#
#     >>> x = Symbol('x', real=True)
#     >>> pprint(solveset(exp(x) - 1, x), use_unicode=False)
#     {2*n*I*pi | n in Integers}
#
#     * If you want to use ``solveset`` to solve the equation in the
#       real domain, provide a real domain. (Using ``solveset_real``
#       does this automatically.)
#
#     >>> R = S.Reals
#     >>> x = Symbol('x')
#     >>> solveset(exp(x) - 1, x, R)
#     {0}
#     >>> solveset_real(exp(x) - 1, x)
#     {0}
#
#     The solution is unaffected by assumptions on the symbol:
#
#     >>> p = Symbol('p', positive=True)
#     >>> pprint(solveset(p**2 - 4))
#     {-2, 2}
#
#     When a :class:`~.ConditionSet` is returned, symbols with assumptions that
#     would alter the set are replaced with more generic symbols:
#
#     >>> i = Symbol('i', imaginary=True)
#     >>> solveset(Eq(i**2 + i*sin(i), 1), i, domain=S.Reals)
#     ConditionSet(_R, Eq(_R**2 + _R*sin(_R) - 1, 0), Reals)
#
#     * Inequalities can be solved over the real domain only. Use of a complex
#       domain leads to a NotImplementedError.
#
#     >>> solveset(exp(x) > 1, x, R)
#     Interval.open(0, oo)

# %% [markdown]
# Equations can be solved using the `solveset()` function. Note that sympy can't solve any equations. It does a good job at solving linear, polynomial, and trigonometric equations.

# %%
sp.solveset(eq1, 'y')
# Out:
# {-(x**3 - x**2*z + 2*x**2 + x - 3)/x}

# %%
eq2 = sp.Eq(lhs = x**3 - x**2 + x - 1, rhs = 0)
sp.solveset(eq2)
# Out:
# {1, -I, I}

# %%
sp.solveset(eq2,x, domain = sp.Reals)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sp.solveset(eq2,x, domain = sp.Reals)
#
# NameError: name 'sp' is not defined

# %%
# Short version: call solveset without creating the equations
sp.solveset(x**3 - x**2 + x - 1, x, domain = sp.Reals)
# Out:
# {1}

# %%
sp.solveset(sp.Eq(lhs = sp.sqrt(x**2), rhs = -x), domain = sp.Reals)
# Out:
# Interval(-oo, 0)

# %% [markdown]
# ## Systems of linear equations
# Systems of equations can be solved with `solve()`.
# https://docs.sympy.org/latest/modules/solvers/solvers.html

# %%
solution = sp.solve((x + 5 * y - 2, -3 * x + 6 * y - 15), (x, y))
solution
# Out:
# {x: -3, y: 1}

# %%
(x,y,z) = sp.symbols( ('x', 'y', 'z') )
sp.solve([x + y - 2*z, y + 4*z],(x, y))
# Out:
# {x: 6*z, y: -4*z}

# %%
theta = sp.Symbol('theta')
sp.solveset(sp.sin(3*theta))
# Out:
# Union(ImageSet(Lambda(_n, 2*_n*pi/3), Integers), ImageSet(Lambda(_n, 2*_n*pi/3 + pi/3), Integers))

# %% [markdown]
# ## Calculus with sympy
#
# ### Limits: `limit`
#
# General syntax: `limit(e, z, z0, dir='+')`

# %%
help(sp.limit)
# Out:
# Help on function limit in module sympy.series.limits:
#
# limit(e, z, z0, dir='+')
#     Computes the limit of ``e(z)`` at the point ``z0``.
#
#     Parameters
#     ==========
#
#     e : expression, the limit of which is to be taken
#
#     z : symbol representing the variable in the limit.
#         Other symbols are treated as constants. Multivariate limits
#         are not supported.
#
#     z0 : the value toward which ``z`` tends. Can be any expression,
#         including ``oo`` and ``-oo``.
#
#     dir : string, optional (default: "+")
#         The limit is bi-directional if ``dir="+-"``, from the right
#         (z->z0+) if ``dir="+"``, and from the left (z->z0-) if
#         ``dir="-"``. For infinite ``z0`` (``oo`` or ``-oo``), the ``dir``
#         argument is determined from the direction of the infinity
#         (i.e., ``dir="-"`` for ``oo``).
#
#     Examples
#     ========
#
#     >>> from sympy import limit, sin, oo
#     >>> from sympy.abc import x
#     >>> limit(sin(x)/x, x, 0)
#     1
#     >>> limit(1/x, x, 0) # default dir='+'
#     oo
#     >>> limit(1/x, x, 0, dir="-")
#     -oo
#     >>> limit(1/x, x, 0, dir='+-')
#     zoo
#     >>> limit(1/x, x, oo)
#     0
#
#     Notes
#     =====
#
#     First we try some heuristics for easy and frequent cases like "x", "1/x",
#     "x**2" and similar, so that it's fast. For all other cases, we use the
#     Gruntz algorithm (see the gruntz() function).
#
#     See Also
#     ========
#
#      limit_seq : returns the limit of a sequence.

# %%
x = sp.Symbol('x')
sp.limit(sp.sin(sp.pi*x)/sp.pi/x , x, 0, dir='+-')
# Out:
# 1

# %% [markdown]
# #### Warning:
# The default value of `dir` is `'+'`, which may lead to some issues if the right limit exists but the limit does not. Take for instance $f(x) = \frac{x}{|x|}$. We have that $\lim_{x \to 0-} f(x) = -1$ and $\lim_{x \to 0+} f(x) = 1$ so that $\lim_{x \to 0} f(x)$ does not exist, but

# %%
expr = x/abs(x)
sp.limit(expr,x,0) # same as limit(expr,x,0, '+')
# Out:
# 1

# %%
sp.limit(expr,x,0,'-')
# Out:
# -1

# %% [markdown]
# If we are more careful and ask for sympy to check that the left and right limits exist and are equal, we get an error:

# %%
sp.limit(expr,x,0,'+-')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 sp.limit(expr,x,0,'+-')
#
# File ~/miniforge3/envs/1mp3/lib/python3.13/site-packages/sympy/series/limits.py:66, in limit(e, z, z0, dir)
#      15 def limit(e, z, z0, dir="+"):
#      16     """Computes the limit of ``e(z)`` at the point ``z0``.
#      17
#      18     Parameters
#    (...)     63      limit_seq : returns the limit of a sequence.
#      64     """
# ---> 66     return Limit(e, z, z0, dir).doit(deep=False)
#
# File ~/miniforge3/envs/1mp3/lib/python3.13/site-packages/sympy/series/limits.py:227, in Limit.doit(self, **hints)
#     225     if r.is_infinite and l.is_infinite:
#     226         return S.ComplexInfinity
# --> 227     raise ValueError("The limit does not exist since "
#     228                      "left hand limit = %s and right hand limit = %s"
#     229                      % (l, r))
#     231 if z0 is S.ComplexInfinity:
#     232     raise NotImplementedError("Limits at complex "
#     233                             "infinity are not implemented")
#
# ValueError: The limit does not exist since left hand limit = -1 and right hand limit = 1

# %%
sp.limit(1/x, x, 0, dir='-')
# Out:
# -oo

# %% [markdown]
# #### Limits at infinity:
# sympy uses `+sp.oo` and `-sp.oo` respectively to represent $+\infty$ and $-\infty$

# %%
sp.limit(sp.sin(sp.pi*x)/sp.pi/x, x, -sp.oo)
# Out:
# 0

# %%
a = sp.Symbol('a')
expr = 1/(x**2+a**2)
expr
# Out:
# 1/(a**2 + x**2)

# %%
sp.limit(expr, x, sp.oo)
# Out:
# 0

# %% [markdown]
# ### Derivatives: `diff`

# %%
x = sp.Symbol('x')
expr = x*sp.ln(x)
expr
# Out:
# x*log(x)

# %%
derivative = sp.diff(expr, x)
# because expr depends only on x, this can be abbreviated as diff(expr)
derivative
# Out:
# log(x) + 1

# %%
# second derivative
sp.diff(sp.diff(expr,x),x)
# Out:
# 1/x

# %%
# Alternative syntax:
sp.diff(expr,x,x)
# or diff(expr,x,2)
# Out:
# 1/x

# %%
sp.diff(expr, x, 5)
# Out:
# -6/x**4

# %% [markdown]
# ### Partial derivatives:
# Explicitely specifying which variable is the derivative computed means that sympy computes *partial derivatives* when expressions include multiple symbols:

# %%
(a,b,c) = sp.symbols( ('a','b','c') )
poly2 = a*x**2+b*x+c
sp.diff(poly2,x)
# Out:
# 2*a*x + b

# %%
x,y = sp.symbols( ('x','y') )
expr_xy = 1 / (x**2 + y**2)
expr_xy
sp.diff(expr_xy,x,2)
# Out:
# 2*(4*x**2/(x**2 + y**2) - 1)/(x**2 + y**2)**2

# %%
sp.diff(expr_xy,x,y)
# Out:
# 8*x*y/(x**2 + y**2)**3

# %%
sp.diff(expr_xy,y,x)
# Out:
# 8*x*y/(x**2 + y**2)**3

# %% [markdown]
# Example: a Gaussian function in dimension 2

# %%
(sigma) = sp.symbols( ('sigma') )
G = 1/sp.sqrt(2*sp.pi)/sigma**2 * sp.exp(-(x**2+y**2)/2/sigma**2)
G
# Out:
# sqrt(2)*exp((-x**2/2 - y**2/2)/sigma**2)/(2*sqrt(pi)*sigma**2)

# %% [markdown]
# ### Taylor series expansion
# The $n^\mathrm{th}$ order *Taylor Polynomial* at $x_0$ of a function $f$ that is $n$ times differentiable with continuous $n^\mathrm{th}$ derivative is given by
# $$
# T_n(x) = \sum_{i=0}^n f^{(i)}(x_0) \frac{(x-x_0)^i}{i!}.
# $$

# %%
def TaylorSeries(f,a,n):
    TS = 0
    fn = f
    for i in range(n):
        TS += fn.subs(x,a) * (x-a)**i / sp.factorial(i)
        fn = sp.diff(fn,x)
    return TS
x = sp.Symbol('x')
f = sp.cos(x)
TaylorSeries(f, sp.pi/4, 10)
# Out:
# -sqrt(2)*(x - pi/4)**9/725760 + sqrt(2)*(x - pi/4)**8/80640 + sqrt(2)*(x - pi/4)**7/10080 - sqrt(2)*(x - pi/4)**6/1440 - sqrt(2)*(x - pi/4)**5/240 + sqrt(2)*(x - pi/4)**4/48 + sqrt(2)*(x - pi/4)**3/12 - sqrt(2)*(x - pi/4)**2/4 - sqrt(2)*(x - pi/4)/2 + sqrt(2)/2

# %% [markdown]
# A small issue here: If we had used a different symbol for the independent variable in the definition of the function $f$, We get a result that makes no sense:

# %%
y = sp.Symbol('y')
g = sp.ln(1+y)
TaylorSeries(g, 0, 5)
# Out:
# log(y + 1)

# %% [markdown]
# We can address this by passing the name of the independent variable to the `TaylorSeries` function:

# %%
def TaylorSeries2(f,x,a,n):
    TS = 0
    fn = f
    for i in range(n):
        TS += fn.subs(x,a) * (x-a)**i / sp.factorial(i)
        fn = sp.diff(fn,x)
    return TS
TaylorSeries2(g,y,0,5)
# Out:
# -y**4/4 + y**3/3 - y**2/2 + y

# %%
b = sp.Symbol('b')
h = sp.ln(b+x)
TaylorSeries2(h,x,0,5)
# Out:
# log(b) + x/b - x**2/(2*b**2) + x**3/(3*b**3) - x**4/(4*b**4)

# %% [markdown]
# Of course, Taylor series are so ubiquitous that they are part of sympy already..

# %%
x = sp.Symbol('x')
Tn_cos = sp.series(sp.cos(x),x,0,10)
Tn_cos
# Out:
# 1 - x**2/2 + x**4/24 - x**6/720 + x**8/40320 + O(x**10)

# %%
x, p, n = sp.symbols( ('x', 'p', 'n'))
expr = 1/(1+x)**p
expr
# Out:
# (x + 1)**(-p)

# %%
Tn = sp.series(expr, x, 0)
sp.simplify(Tn)
# Out:
# 1 - p*x + p*x**2*(p + 1)/2 - p*x**3*(p + 1)*(p + 2)/6 + p*x**4*(p + 1)*(p + 2)*(p + 3)/24 - p*x**5*(p + 1)*(p + 2)*(p + 3)*(p + 4)/120 + O(x**6)

# %% [markdown]
# ### Integrals, antiderivatives
#
# * indefinite integral: `integrate(f, variable)`
# * definite integral: `integrate(f, (variable,a,b))`

# %%
gauss1D = -sp.exp(-x/2)/2
iGauss1D = sp.integrate(gauss1D,x)
#also gauss1D.integrate(x)
iGauss1D
# Out:
# exp(-x/2)

# %%
sp.integrate(sp.log(x), x)
# Out:
# x*log(x) - x

# %%
expr = sp.integrate(sp.exp(-x), (x,0,sp.oo))
expr
# Out:
# 1

# %%
x = sp.Symbol('x',Real = True)
a = sp.Symbol('a',Real = True)
expr = (x**2+a**2)
expr
# Out:
# a**2 + x**2

# %%
sp.simplify(sp.integrate(expr,x))
# Out:
# x*(a**2 + x**2/3)

# %%
Phi = (-y * sp.exp(-x*y), 1-x*sp.exp(-x*y))
Phi[0].integrate(x)
G = sp.exp(-x**2/2)/sp.sqrt(2*sp.pi)
sp.integrate(G,(x,-sp.oo,sp.oo))
G.integrate((x, -sp.oo, sp.oo))
# Out:
# 1

# %%
G2D = sp.exp(-(x**2+y**2)/2)/sp.sqrt(2*sp.pi)
G2D = (x**2+y**2)
sp.integrate(G2D,(x,-1,1), (y, -1, 1))
# Out:
# 8/3

# %% [markdown]
# ## An optimization problem:
# Let $a$, and $b$  be two unknown parameters, and let $$f(x) = \frac{24 x \left(a - 4 x\right) + \left(2 a - 16 x\right) \left(b - 4 x\right)}{\left(b - 4 x\right)^{4}}.$$
# 1. Find $a$ and $b>0$ such that $\frac{\mathrm{d}f}{\mathrm{d}x}(0) = 0$ and $\frac{\mathrm{d}^2f}{\mathrm{d}x^2}(0) = -1$
# 2. For these values of $a$ and $b$, compute
#    - $\lim_{x \to 0} f(x)$
#    - $\lim_{x \to oo} f(x)$
#    - $\int f(x)\, dx$
#    - $\int_1^\infty f(x)\, dx$.

# %%
x = sp.Symbol("x")
a = sp.Symbol("a", Real = True)
b = sp.Symbol("b", Positive=True)
f = (24 * x * (a - 4 * x) + 2 * (a - 8 * x) * (b - 4 * x)) / ((b - 4 * x) ** 4)
f.subs(x,0)
# Out:
# 2*a/b**3

# %%
fx = sp.diff(f,x)
sp.simplify(fx)
# Out:
# 16*(24*x*(a - 4*x) + 2*(a - 8*x)*(b - 4*x) + (b - 4*x)*(a - b - 4*x))/(b - 4*x)**5

# %%
fxx = sp.diff(f,x,x)
sp.simplify(fxx)
# Out:
# 64*(120*x*(a - 4*x) + 10*(a - 8*x)*(b - 4*x) - (b - 4*x)**2 + 8*(b - 4*x)*(a - b - 4*x))/(b - 4*x)**6

# %%
Eq1 = Eq(fx.subs({x:0}), 0)
Eq2 = Eq(fxx.subs({x:0}), -1)

# %%
solutions = solve([Eq1, Eq2], (a,b))
solutions

# %%
astar = solutions[1][0]
bstar = solutions[1][1]
fab = f.subs( {a:astar, b:bstar})
fab

# %%
fxx.subs( {x:0, a:astar,b:bstar} )

# %%
limit(fab,x,0)

# %%
limit(fab,x,oo)

# %%
integrate(fab,x)

# %%
sols = solveset(fab)
sols

# %%
xstar = sols.args[1]
xstar

# %%
Area = integrate(fab,(x,0,xstar))
Area

# %%
Areasimp = factor(simplify(Area))
Areasimp

# %%
Areasimp.evalf()

# %%
fnp = lambdify(x,fab)
fig, ax = plt.subplots()
X = np.linspace(0,10,1001)

(ymin,ymax) = (-2,fnp(0))
ax.plot(X,fnp(X),label = 'fab')
ax.set_ylim(ymin,ymax)
ax.spines[['left', 'bottom']].set_position('zero')
ax.spines[['top', 'right']].set_visible(False)
ax.plot(X,fnp(0)-X**2/2)
plt.plot((np.sqrt(2)*3**(1/4)/2, np.sqrt(2)*3**(1/4)/2),(ymin,ymax))
ax.legend()
