# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Monday March 16th 2026

# %% [markdown]
# ## Introduction to Pandas
#
# ![Panda Picture](panda.jpg)

# %% [markdown]
# - We have seen how Numpy arrays are great tools for working with data of a uniform type.
#     - In Pythonic words, we say Numpy arrays are homogeneous containers.
#     - This allows Numpy arrays to have a single type - called their dtype.

# %%
A = np.array([[1,2,3],[4,5,6]])
B = np.array([[1.,2.,3.],[4.,5,6]])
print(f"A = {A}")
print(f"B = {B}")

# %%
print(f"A has dtype : {A.dtype}")
print(f"B has dtype : {B.dtype}")

# %% [markdown]
# Having a homogeneous type has many advantages (there are three key ones lets try to name them here!)
#
# - Vectorization
# - Only have to compare/cast types once
# - Nice memory model

# %% [markdown]
# However, we are oftentimes faced with data that is not homogeneous. In these cases, it would be nice to have a library with some of the similar functionality as Numpy i.e. **vectorization** and **columnization**, without the constraint of homogeneity.
#
# Such a library is **Pandas**.

# %% [markdown]
# ### Pandas
#
# Just as Numpy offers us the new data type of Numpy nd-arrays, Pandas comes with two new data types called **series** and **data frames**.
#
# ![Panda picture](KungFuPanda.png)

# %% [markdown]
# ### Series
#
# A **series** is a one-dimensional labeled array.

# %%
a = [1, 7, 2]
ser1 = pd.Series(data = a)

print(ser1)

# %%
print(ser1[2])

# %%
ser2 = pd.Series(data = a, index = ["x", "y", "z"])
print(ser2)

# %%
d = {"a" : 1, "b" : 2, "c" : 3}
ser = pd.Series(data = d, index = ["a","b","c"])
print(ser)

# %% [markdown]
# ### Labels are helpful
#
# Suppose we have two datasets. They have some common data points, but they do not overlap completely. How can we make sure that arithmetic operations on them are well defined?

# %%
hw1_data = {'John' : 72.0, 'Nathan' : 100.0, 'Matthew' : 88.9}
hw2_data = {'Nathan' : 100.0, 'Matthew' : 93.9}

hw1 = pd.Series(data = hw1_data)
hw2 = pd.Series(data = hw2_data)

# %%
hw_avg = (hw1 + hw2)/2

hw_avg

# %% [markdown]
# **Notice:** The same task would a lot more work with Numpy arrays.
#
# **However** this brings up an interesting point. Oftentimes our data will be incomplete. Pandas deals with incomplete data by labelling it with *NaN* standing for *Not a Number*. Dealing with missing data is one of the most important topics in data science (falling into the larger category of data sanitization). We will discuss how Pandas can help us deal with *NaN* values shortly.

# %% [markdown]
# ### Converting series back to other types
#
# Pandas series can be converted to many other Python container types.

# %%
l_ser = ser.to_list()
print(l_ser)
d_ser = ser.to_dict()
print(d_ser)
np_ser = ser.to_numpy()
print(np_ser)

# %% [markdown]
# ### Names
#
# Pandas series also have a `name` attribute. This will become useful when creating `DataFrames` from Series.

# %%
ser.name = 'My Series'

# %%
ser

# %% [markdown]
# ### DataFrames
#
# A **DataFrame** is a two-dimensional labeled data structure that consists of columns and rows. A DataFrame represents a spreadsheet-like data structure where each column is a **Series**.

# %%
data = {
    "Name" : ["John", "Nathan", "Lily", "Corrin"],
    "Age" : [26,27,19,26],
    "City" : ["Hamilton", "Dundas", "Halifax", "Charlottetown"]
}

df = pd.DataFrame(data)

df

# %%
data = [
    ["John", 26, "Hamilton"],
    ['Nathan', 27, "Dundas"],
    ["Lily", 19, "Halifax"],
    ["Corrin", 26, "Charlottetown"]
]

unique_id = [400130523, 400127887, 40130877, 555555555]

cols = ["Name", "Age", "City"]

df = pd.DataFrame(data = data, columns = cols, index = unique_id)

df

# %%
df[["Name", "Age"]]

# %%
df["City"]

# %% [markdown]
# What if we want to see a row instead of a column?
#
# Here we can use the `loc` method!

# %%
df.loc[400130523]

# %%
df.loc[[400130523,555555555]]

# %% [markdown]
# If we don't want to use the row identifier, we can also talk about a row by its index using `iloc`.

# %%
df.iloc[1]

# %% [markdown]
# We can also look at a range of columns or locations, or even extract an entire sub-dataframe.

# %%
df[["Name", "Age"]]

# %%
df.loc[400130523:40130877, "Name" : "Age"]

# %% [markdown]
# ### Reading in from file

# %%
df = pd.read_csv('grades.csv')

# %%
df

# %% [markdown]
# Sometimes datasets will be too large to view in one frame. The `head()` command lets us see the first 5 rows and the `tail()` command lets us see the last 5.

# %%
df.head()

# %%
df.tail()

# %% [markdown]
# To gain some more insight, we can also ask for a high level description of our data.

# %%
df.describe()

# %%
df[' Quizzes average']

# %%
df.columns

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Tuesday March 16th 2026
# ### Announcements
# - Assignment 4 due March 20th at 11:59pm
# ### Last time
# - Introduction to Pandas. We saw Pandas two new types: **Series** and **DataFrames**.
#     - A **Series** is a labeled one-dimensional array. (like a vector)
#     - A **Dataframe** is a labeled two-dimensional array (where only the columns are required to be homogeneous). Each column of a dataframe is a series.

# %%
df = pd.read_csv('grades.csv')

# %%
df.head()
# Out:
#   # First name           Last name   Student number   Quizzes average  \
# 0        BARRY                LAMB        620565656                96
# 1      NARIMAN   PELUCHONDELAGARZA        107856531                94
# 2       VITALY                KHAN          7943944                92
# 3      NATALYA           SUTRADHAR        114037001                90
# 4      MAGARET               HIRJI        581943811                88
#
#     HW1 mark   HW2 mark   HW3 mark   Exam1 mark   Exam2 mark   Final exam mark
# 0         77         82         91           88           78                91
# 1         76         87         90           90           67                88
# 2         79         85         92           76           60                87
# 3         75         78         88           90           67                84
# 4         76         91         98           96           56                81

# %%
df.tail()
# Out:
#     # First name    Last name   Student number   Quizzes average   HW1 mark  \
# 246       JANAYA     ELZOEIBY        248015969                94         72
# 247       PATRYK    BERNIQUER        970187185                95         72
# 248      ARIANNA   DMITROVICH        300391145                91         73
# 249      CHERISE    MILEUSNIC        149614639                92         78
# 250      DUMITRU         SHAH        849296811                94         65
#
#       HW2 mark   HW3 mark   Exam1 mark   Exam2 mark   Final exam mark
# 246         82         91           92           69                93
# 247         88         94           88           67                95
# 248         84         94           96           75                83
# 249         79         91           90           65                90
# 250         86         87           83           74                85

# %%
df.loc[len(df)+1] = ["Mike", "Wazowski", 400130523, 29.9, 29.9, 29.9, 29.9, 22.2, 22.2, 30.2]

# %%
df['New column'] = [i for i in range(253)]

# %% [markdown]
# ### Filtering
#
# We can use similar Boolean syntax as in Numpy to filter through data frames and series.

# %%
df.head()
# Out:
#   # First name           Last name   Student number   Quizzes average  \
# 0        BARRY                LAMB        620565656              96.0
# 1      NARIMAN   PELUCHONDELAGARZA        107856531              94.0
# 2       VITALY                KHAN          7943944              92.0
# 3      NATALYA           SUTRADHAR        114037001              90.0
# 4      MAGARET               HIRJI        581943811              88.0
#
#     HW1 mark   HW2 mark   HW3 mark   Exam1 mark   Exam2 mark   Final exam mark
# 0       77.0       82.0       91.0         88.0         78.0              91.0
# 1       76.0       87.0       90.0         90.0         67.0              88.0
# 2       79.0       85.0       92.0         76.0         60.0              87.0
# 3       75.0       78.0       88.0         90.0         67.0              84.0
# 4       76.0       91.0       98.0         96.0         56.0              81.0

# %%
df[df[' Final exam mark']> 92.0]
# Out:
#     # First name      Last name   Student number   Quizzes average   HW1 mark  \
# 5          RAINA      SUTRADHAR        367541502              90.0       70.0
# 21        GREGOR   GOPAULROLDAN         75524279              89.0       83.0
# 24       MARITZA            YIN        128992445              93.0       82.0
# 39        MARITA          HUANG        217623542              81.0       79.0
# 57        TAWNYA        KHURANA        187126246             100.0       69.0
# 67         AHMET        VEERMAN        485438097              93.0       68.0
# 74        FORBES      MILEUSNIC         91063682              89.0       77.0
# 86     SATWINDER          ISLAM        679421923              97.0       67.0
# 91      MARY-LOU        OLUTAYO        119625290              98.0       67.0
# 118      ORLANDO           KHAN        485689330              98.0       73.0
# 129        DONNA         SHARMA        185017481             100.0       85.0
# 154          YAM          BAYAN          8912621              96.0       77.0
# 159    CELESTINE           AZOM        454169056              91.0       62.0
# 166      VIRGINA          ANGEL        832591342              86.0       80.0
# 171       KOLTEN      MACDONALD        983697220              90.0       73.0
# 186        ANHAD        WILFRED        731558064              89.0       81.0
# 188       YUYING      DEHMESHKI        285211298              95.0       77.0
# 202       MICHAL         PRESTI        714449327             100.0       76.0
# 212      NATACHA           HOOD        531062921             100.0       74.0
# 213        MARWA         MOHSIN        757587905             100.0       88.0
# 215       MADDIE            LIU         99421869              96.0       74.0
# 227          RIA     PRABAHARAN        209237590              93.0       79.0
# 234     ANTONINA        VECCHIO        226246762              90.0       76.0
# 246       JANAYA       ELZOEIBY        248015969              94.0       72.0
# 247       PATRYK      BERNIQUER        970187185              95.0       72.0
#
#       HW2 mark   HW3 mark   Exam1 mark   Exam2 mark   Final exam mark
# 5         84.0       91.0         91.0         59.0              95.0
# 21        80.0       93.0         94.0         63.0              95.0
# 24        98.0       87.0         90.0         64.0              97.0
# 39        81.0       92.0         81.0         72.0              94.0
# 57        91.0       92.0         87.0         64.0              93.0
# 67        84.0       83.0         87.0         71.0              93.0
# 74        82.0       92.0         78.0         69.0              95.0
# 86        84.0       83.0         84.0         66.0              93.0
# 91        83.0       88.0         82.0         63.0             100.0
# 118       87.0       94.0         79.0         72.0              93.0
# 129       84.0       90.0         90.0         59.0              99.0
# 154       82.0       88.0         95.0         72.0              93.0
# 159       79.0       93.0         81.0         70.0              95.0
# 166       86.0       87.0         85.0         63.0              93.0
# 171       84.0       86.0         88.0         69.0              94.0
# 186       80.0       82.0         97.0         67.0              94.0
# 188       74.0       93.0         89.0         65.0              94.0
# 202       81.0       90.0         94.0         67.0              96.0
# 212       91.0       85.0         80.0         61.0              95.0
# 213       77.0       86.0         89.0         64.0              95.0
# 215       80.0       90.0         85.0         62.0              95.0
# 227       82.0       88.0         87.0         62.0              96.0
# 234       93.0       93.0         83.0         62.0              93.0
# 246       82.0       91.0         92.0         69.0              93.0
# 247       88.0       94.0         88.0         67.0              95.0

# %%
df[(df[' Final exam mark']>92.0) & (df[' Quizzes average']> 98.0)]
# Out:
#     # First name  Last name   Student number   Quizzes average   HW1 mark  \
# 57        TAWNYA    KHURANA        187126246             100.0       69.0
# 129        DONNA     SHARMA        185017481             100.0       85.0
# 202       MICHAL     PRESTI        714449327             100.0       76.0
# 212      NATACHA       HOOD        531062921             100.0       74.0
# 213        MARWA     MOHSIN        757587905             100.0       88.0
#
#       HW2 mark   HW3 mark   Exam1 mark   Exam2 mark   Final exam mark
# 57        91.0       92.0         87.0         64.0              93.0
# 129       84.0       90.0         90.0         59.0              99.0
# 202       81.0       90.0         94.0         67.0              96.0
# 212       91.0       85.0         80.0         61.0              95.0
# 213       77.0       86.0         89.0         64.0              95.0

# %% [markdown]
# ### Sorting
#
# We may also sort a data frame by a column or row. Note that the data being sorted must have a well defined order.
#
# **Note:** We may choose specifically the sorting algorithm we wish to use. By default pandas uses quicksort.

# %%
df.sort_values(' Final exam mark', ascending = False, kind = 'quicksort').head()
# Out:
#     # First name    Last name   Student number   Quizzes average   HW1 mark  \
# 91      MARY-LOU      OLUTAYO        119625290              98.0       67.0
# 129        DONNA       SHARMA        185017481             100.0       85.0
# 24       MARITZA          YIN        128992445              93.0       82.0
# 202       MICHAL       PRESTI        714449327             100.0       76.0
# 227          RIA   PRABAHARAN        209237590              93.0       79.0
#
#       HW2 mark   HW3 mark   Exam1 mark   Exam2 mark   Final exam mark
# 91        83.0       88.0         82.0         63.0             100.0
# 129       84.0       90.0         90.0         59.0              99.0
# 24        98.0       87.0         90.0         64.0              97.0
# 202       81.0       90.0         94.0         67.0              96.0
# 227       82.0       88.0         87.0         62.0              96.0

# %%
df.sort_values(' Final exam mark', ascending = False, kind = 'mergesort').tail()
# Out:
#     # First name   Last name   Student number   Quizzes average   HW1 mark  \
# 59      NATHALIE       GEBEL        980187871              93.0       75.0
# 61           LIN   MALKOVICH        839455529              89.0       70.0
# 235      EVERETT      FANNIN        134748666              97.0       64.0
# 241         TINA    FERNANDO        846493083              91.0       66.0
# 252         Mike    Wazowski        400130523              29.9       29.9
#
#       HW2 mark   HW3 mark   Exam1 mark   Exam2 mark   Final exam mark
# 59        85.0       93.0         95.0         53.0              75.0
# 61        93.0       91.0         89.0         56.0              75.0
# 235       83.0       92.0         76.0         60.0              75.0
# 241       88.0       89.0         83.0         68.0              74.0
# 252       29.9       29.9         22.2         22.2              30.2

# %% [markdown]
# ### Example calculation involving grades

# %%
df = pd.read_csv('grades.csv')

# %%
df.columns
# Out:
# Index(['# First name', ' Last name', ' Student number', ' Quizzes average',
#        ' HW1 mark', ' HW2 mark', ' HW3 mark', ' Exam1 mark', ' Exam2 mark',
#        ' Final exam mark'],
#       dtype='object')

# %% [markdown]
# ### Final grading scheme
# 1. Scheme 1
# - 10% Quizzes
# - 20% HW
# - 40% Exams (20% each)
# - 30% Final Exam
# 2. Scheme 2
# - 10% Quizzes
# - 20% HW
# - 20% Exams (Best 1 of 2)
# - 50% Final Exam

# %%
final_grade1 = 0.1*df[' Quizzes average'] + 0.2*((df[' HW1 mark']+ df[' HW2 mark']+ df[' HW3 mark'])/3) + 0.2*(df[' Exam1 mark']) + 0.2*(df[' Exam2 mark'])+0.3*(df[' Final exam mark'])

final_grade2 = 0.1*df[' Quizzes average'] + 0.2*((df[' HW1 mark']+ df[' HW2 mark']+ df[' HW3 mark'])/3) + 0.2*(df[[' Exam1 mark', ' Exam2 mark']].max(axis = 1))+0.5*(df[' Final exam mark'])
df.insert(10,'Final grade scheme 1', final_grade1)
df.insert(11, 'Final grade scheme 2', final_grade2)

# %%
df.head()
# Out:
#   # First name           Last name   Student number   Quizzes average  \
# 0        BARRY                LAMB        620565656                96
# 1      NARIMAN   PELUCHONDELAGARZA        107856531                94
# 2       VITALY                KHAN          7943944                92
# 3      NATALYA           SUTRADHAR        114037001                90
# 4      MAGARET               HIRJI        581943811                88
#
#     HW1 mark   HW2 mark   HW3 mark   Exam1 mark   Exam2 mark  \
# 0         77         82         91           88           78
# 1         76         87         90           90           67
# 2         79         85         92           76           60
# 3         75         78         88           90           67
# 4         76         91         98           96           56
#
#     Final exam mark  Final grade scheme 1  Final grade scheme 2
# 0                91             86.766667             89.366667
# 1                88             84.066667             88.266667
# 2                87             79.566667             84.966667
# 3                84             81.666667             85.066667
# 4                81             81.166667             86.166667

# %%
final_grade = df[['Final grade scheme 1', 'Final grade scheme 2']].max(axis = 1)
df.insert(12, 'Final grade', final_grade)

# %%
df.head()
# Out:
#   # First name           Last name   Student number   Quizzes average  \
# 0        BARRY                LAMB        620565656                96
# 1      NARIMAN   PELUCHONDELAGARZA        107856531                94
# 2       VITALY                KHAN          7943944                92
# 3      NATALYA           SUTRADHAR        114037001                90
# 4      MAGARET               HIRJI        581943811                88
#
#     HW1 mark   HW2 mark   HW3 mark   Exam1 mark   Exam2 mark  \
# 0         77         82         91           88           78
# 1         76         87         90           90           67
# 2         79         85         92           76           60
# 3         75         78         88           90           67
# 4         76         91         98           96           56
#
#     Final exam mark  Final grade scheme 1  Final grade scheme 2  Final grade
# 0                91             86.766667             89.366667    89.366667
# 1                88             84.066667             88.266667    88.266667
# 2                87             79.566667             84.966667    84.966667
# 3                84             81.666667             85.066667    85.066667
# 4                81             81.166667             86.166667    86.166667

# %% [markdown]
# ### Dealing with missing data
#
# Let's now try to accomplish the same goal as before, but this time with a more realistic data set.

# %%
gradeBook = pd.read_csv('grades_missing.csv', na_values = [' '])

# %%
gradeBook
# Out:
#     # First name           Last name   Student number   Quizzes average  \
# 0          BARRY                LAMB        620565656              96.0
# 1        NARIMAN   PELUCHONDELAGARZA        107856531              94.0
# 2         VITALY                KHAN          7943944              92.0
# 3        NATALYA           SUTRADHAR        114037001              90.0
# 4        MAGARET               HIRJI        581943811              88.0
# ..           ...                 ...              ...               ...
# 246       JANAYA            ELZOEIBY        248015969              94.0
# 247       PATRYK           BERNIQUER        970187185              95.0
# 248      ARIANNA          DMITROVICH        300391145              91.0
# 249      CHERISE           MILEUSNIC        149614639              92.0
# 250      DUMITRU                SHAH        849296811              94.0
#
#       HW1 mark   HW2 mark   HW3 mark   Exam1 mark   Exam2 mark  \
# 0         77.0        NaN       91.0          NaN          NaN
# 1         76.0       87.0       90.0         90.0         67.0
# 2         79.0       85.0       92.0         76.0         60.0
# 3         75.0       78.0       88.0         90.0         67.0
# 4         76.0       91.0       98.0         96.0         56.0
# ..         ...        ...        ...          ...          ...
# 246       72.0       82.0       91.0         92.0         69.0
# 247       72.0       88.0       94.0         88.0         67.0
# 248       73.0       84.0       94.0         96.0         75.0
# 249       78.0       79.0       91.0         90.0         65.0
# 250       65.0       86.0       87.0          NaN          NaN
#
#       Final exam mark
# 0                  91
# 1                  88
# 2                  87
# 3                  84
# 4                  81
# ..                ...
# 246                93
# 247                95
# 248                83
# 249                90
# 250                85
#
# [251 rows x 10 columns]

# %% [markdown]
# We must choose how we deal with NaN values. In the case of grades, inserting zero works, but in other data sets this will not make sense. For instance, in some cases, inserting the mean of the data set is best.

# %%
gradeBook = gradeBook.fillna(0)

# %%
final_grade1 = 0.1*gradeBook[' Quizzes average'] + 0.2*((gradeBook[' HW1 mark']+ gradeBook[' HW2 mark']+ gradeBook[' HW3 mark'])/3) + 0.2*(gradeBook[' Exam1 mark']) + 0.2*(gradeBook[' Exam2 mark'])+0.3*(gradeBook[' Final exam mark'])

final_grade2 = 0.1*gradeBook[' Quizzes average'] + 0.2*((gradeBook[' HW1 mark']+ gradeBook[' HW2 mark']+ gradeBook[' HW3 mark'])/3) + 0.2*(gradeBook[[' Exam1 mark', ' Exam2 mark']].max(axis = 1))+0.5*(gradeBook[' Final exam mark'])

gradeBook.insert(10,'Final grade scheme 1', final_grade1)
gradeBook.insert(11, 'Final grade scheme 2', final_grade2)

# %%
final_grade = gradeBook[['Final grade scheme 1', 'Final grade scheme 2']].max(axis = 1)
gradeBook.insert(12, 'Final grade', final_grade)

# %%
gradeBook
# Out:
#     # First name           Last name   Student number   Quizzes average  \
# 0          BARRY                LAMB        620565656              96.0
# 1        NARIMAN   PELUCHONDELAGARZA        107856531              94.0
# 2         VITALY                KHAN          7943944              92.0
# 3        NATALYA           SUTRADHAR        114037001              90.0
# 4        MAGARET               HIRJI        581943811              88.0
# ..           ...                 ...              ...               ...
# 246       JANAYA            ELZOEIBY        248015969              94.0
# 247       PATRYK           BERNIQUER        970187185              95.0
# 248      ARIANNA          DMITROVICH        300391145              91.0
# 249      CHERISE           MILEUSNIC        149614639              92.0
# 250      DUMITRU                SHAH        849296811              94.0
#
#       HW1 mark   HW2 mark   HW3 mark   Exam1 mark   Exam2 mark  \
# 0         77.0        0.0       91.0          0.0          0.0
# 1         76.0       87.0       90.0         90.0         67.0
# 2         79.0       85.0       92.0         76.0         60.0
# 3         75.0       78.0       88.0         90.0         67.0
# 4         76.0       91.0       98.0         96.0         56.0
# ..         ...        ...        ...          ...          ...
# 246       72.0       82.0       91.0         92.0         69.0
# 247       72.0       88.0       94.0         88.0         67.0
# 248       73.0       84.0       94.0         96.0         75.0
# 249       78.0       79.0       91.0         90.0         65.0
# 250       65.0       86.0       87.0          0.0          0.0
#
#       Final exam mark  Final grade scheme 1  Final grade scheme 2  Final grade
# 0                  91             48.100000             66.300000    66.300000
# 1                  88             84.066667             88.266667    88.266667
# 2                  87             79.566667             84.966667    84.966667
# 3                  84             81.666667             85.066667    85.066667
# 4                  81             81.166667             86.166667    86.166667
# ..                ...                   ...                   ...          ...
# 246                93             85.833333             90.633333    90.633333
# 247                95             85.933333             91.533333    91.533333
# 248                83             84.933333             86.533333    86.533333
# 249                90             83.733333             88.733333    88.733333
# 250                85             50.766667             67.766667    67.766667
#
# [251 rows x 13 columns]

# %% [markdown]
# ### Writing to csv

# %%
gradeBook.to_csv('gradesWithFilledNaN.csv')

# %% [markdown]
# Depending on the kind of data, sometimes it is best to remove all data that contains *NaN* values. For instance, when getting ethics approval for a research project involving a survey, it is sometimes required that all partially completed surveys be removed from the data set.
#
# We can use the `dropna()` command for this.

# %% [markdown]
# ### Writing to Excel

# %%
# %pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /opt/anaconda3/envs/1mp3/lib/python3.13/site-packages (from openpyxl) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
gradeBook.to_excel('gradeBook.xlsx')
