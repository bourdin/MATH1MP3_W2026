# %% [markdown]
# # Monday March 16th 2026
#
# ### Announcements
# - Assignment 4 due March 20th at 11:59pm

# %% [markdown]
# # Chapter 10 Matplotlib - 3, Animations, interactive plots
#
# Back to the motion in space example

# %%
import matplotlib.pyplot as plt
# %matplotlib widget
import numpy as np

# %%
plt.close('all')

fig = plt.figure() 
ax = fig.add_subplot(projection='3d')

def x(t):
    return np.cos(t)
def y(t):
    return np.sin(t)
def z(t):
    return t / 4. / np.pi

T = np.linspace(0,4*np.pi, 101)
ax.plot(x(T), y(T), z(T), linewidth = 2, label='parametric curve')
ax.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Let's make this interactive:
#
# First, we write a function that plots one frame:

# %%
plt.close('all')
from ipywidgets import interact
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

# Write a function that plots a single 
# frame based on a value of t
def plot(t):
    # make a blank plot
    ax.cla()
    # plotting the parametric curve
    T = np.linspace(0, 4*np.pi, 201)
    ax.plot(x(T), y(T), z(T), linewidth = 2, label='parametric curve')
    # adding a point a t
    ax.scatter(x(t), y(t), z(t), marker = 'o', color = 'red') 
plot(np.pi)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
interact(plot, t = (0,4*np.pi, np.pi/200))
# Out:
# interactive(children=(FloatSlider(value=6.267477343911638, description='t', max=12.566370614359172, step=0.015…
# <function __main__.plot(t)>

# %% [markdown]
# The *velocity* vector is the vector $(x'(t), y'(t), z'(t))$. Let's add it to the plot

# %%
def xp(t):
    return -np.sin(t)
def yp(t):
    return np.cos(t)
def zp(t):
    return 1 / 4. / np.pi

def plot2(t):
    ax.cla()
    T = np.linspace(0, 4*np.pi, 201)
    ax.plot(x(T), y(T), z(T), linewidth = 2, label='parametric curve')
    # plots the red dot at point t
    ax.scatter(x(t), y(t), z(t), marker = 'o', color = 'red') 
    # plots the vector at point t
    ax.quiver(x(t), y(t), z(t), xp(t), yp(t), zp(t), color='blue', linewidth=3, label = 'v(t)')

# %%
plt.close('all')
from ipywidgets import interact
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

interact(plot2, t = (0,4*np.pi, np.pi/200))
# Out:
# interactive(children=(FloatSlider(value=6.267477343911638, description='t', max=12.566370614359172, step=0.015…
# <function __main__.plot2(t)>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
