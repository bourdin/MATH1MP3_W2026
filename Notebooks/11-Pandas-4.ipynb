# %% [markdown]
# # 11-4 Oil prices data from statcan

# %%
import pandas as pd

gp = pd.read_csv("1810000101_databaseLoadingData.csv", skipinitialspace=True)
gp
# Out:
#      REF_DATE                                 GEO             DGUID  \
# 0     2016-01                              Canada    2016A000011124
# 1     2016-02                              Canada    2016A000011124
# 2     2016-03                              Canada    2016A000011124
# 3     2016-04                              Canada    2016A000011124
# 4     2016-05                              Canada    2016A000011124
# ...       ...                                 ...               ...
# 2313  2025-10  Yellowknife, Northwest Territories  2011A00056106023
# 2314  2025-11  Yellowknife, Northwest Territories  2011A00056106023
# 2315  2025-12  Yellowknife, Northwest Territories  2011A00056106023
# 2316  2026-01  Yellowknife, Northwest Territories  2011A00056106023
# 2317  2026-02  Yellowknife, Northwest Territories  2011A00056106023
#
#                                            Type of fuel              UOM  \
# 0     Regular unleaded gasoline at self service fill...  Cents per litre
# ...

# %%
gpGTA = gp[gp['GEO'] == 'Toronto, Ontario']
gpGTA['REF_DATE']
# Out:
# 976     2016-01
# 977     2016-02
# 978     2016-03
# 979     2016-04
# 980     2016-05
#          ...
# 1093    2025-10
# 1094    2025-11
# 1095    2025-12
# 1096    2026-01
# 1097    2026-02
# Name: REF_DATE, Length: 122, dtype: object

# %%
places
# Out:
# array(['Canada', "St. John's, Newfoundland and Labrador",
#        'Charlottetown and Summerside, Prince Edward Island',
#        'Halifax, Nova Scotia', 'Saint John, New Brunswick',
#        'Québec, Quebec', 'Montréal, Quebec',
#        'Ottawa-Gatineau, Ontario part, Ontario/Quebec',
#        'Toronto, Ontario', 'Thunder Bay, Ontario', 'Winnipeg, Manitoba',
#        'Regina, Saskatchewan', 'Saskatoon, Saskatchewan',
#        'Edmonton, Alberta', 'Calgary, Alberta',
#        'Vancouver, British Columbia', 'Victoria, British Columbia',
#        'Whitehorse, Yukon', 'Yellowknife, Northwest Territories'],
#       dtype=object)

# %%
gp[gp.GEO == 'Canada']
# Out:
#     REF_DATE     GEO           DGUID  \
# 0    2016-01  Canada  2016A000011124
# 1    2016-02  Canada  2016A000011124
# 2    2016-03  Canada  2016A000011124
# 3    2016-04  Canada  2016A000011124
# 4    2016-05  Canada  2016A000011124
# ..       ...     ...             ...
# 117  2025-10  Canada  2016A000011124
# 118  2025-11  Canada  2016A000011124
# 119  2025-12  Canada  2016A000011124
# 120  2026-01  Canada  2016A000011124
# 121  2026-02  Canada  2016A000011124
#
#                                           Type of fuel              UOM  \
# 0    Regular unleaded gasoline at self service fill...  Cents per litre
# 1    Regular unleaded gasoline at self service fill...  Cents per litre
# 2    Regular unleaded gasoline at self service fill...  Cents per litre
# 3    Regular unleaded gasoline at self service fill...  Cents per litre
# 4    Regular unleaded gasoline at self service fill...  Cents per litre
# ..                                                 ...              ...
# ...
